# %% [markdown]
# # SQL

# %% [markdown]
# ## Дейт (гл. 1) ✅

# %% [markdown]
# ![imfddfsdfdsfsdfage.png](attachment:image.png)

# %% [markdown]
# ### Приведите результат выборки

# %% [markdown]
# ![imaаврппрпывавпge.png](attachment:image.png)

# %% [markdown]
# 1.
# ```SQL
# SELECT WINE, PRODUCER
# FROM CELLAR
# WHERE BIN# = 72;
# ```
# | WINE | PRODUCER |
# | --- | --- |
# | Zinfandel | Rafanelli |

# %% [markdown]
# 2.
# ```SQL
# SELECT WINE, PRODUCER
# FROM CELLAR
# WHERE YEAR > 2000;
# ```
# | WINE | PRODUCER |
# | --- | --- |
# | Chardonnay | Buena Vista |
# | Chardonnay | Geyser Peak |
# | Joh. Riesling | Jekel |
# | Fume Blanc | Ch. St. Jean |
# | Gewurztraminer | Ch. St. Jean |

# %% [markdown]
# 3.
# ```SQL
# SELECT BIN#, WINE, YEAR
# FROM CELLAR
# WHERE READY < 2003;
# ```
# | BIN# | WINE | YEAR |
# | --- | --- | --- |
# | 6 | Chardonnay | 2002 |
# | 22 | Fume Blanc | 2002 |
# | 52 | Pinot Noir | 2002 |

# %% [markdown]
# 4.
# ```SQL
# SELECT WINE, BIN#, YEAR /*выбрать вино, номер бочки и год разлива*/
# FROM CELLAR /*из базы данных погреб*/
# WHERE PRODUCER = 'Robt. Mondavi' AND BOTTLES > 6; /*где производитель=..., а число бутылок больше 6*/
# ```
# | WINE | BIN# | YEAR |
# | --- | --- | --- |
# | Cab. Sauvignon | 48 | 1997 |

# %% [markdown]
# ### Приведите результат изменения таблицы

# %% [markdown]
#  ![iцвуыауцфуаыффвыаmage.png](attachment:image.png)

# %% [markdown]
# 1.
# ```SQL
# INSERT
# INTO CELLAR (BIN#, WINE, PRODUCER, YEAR, BOTTLES, READY)f?
# VALUES (80, 'Syrah', 'Meidian', 1998, 12, 2003);
# ```
# | BIN# | WINE | PRODUCER | YEAR | BOTTLES | READY|
# | --- | --- | --- | --- | --- | --- |
# | ... | ... | ... | ... | ... | ... |
# | 80 | Syrah | Meidian | 1998 | 12 | 2003 |

# %% [markdown]
# 2.
# ```SQL
# DELETE
# FROM CELLAR
# WHERE READY > 2004;
# ```
# ![imSDFSDFDSFDSFSDFage.png](attachment:image.png)

# %% [markdown]
# 3.
# ```SQL
# UPDATE CELLAR
# SET BOTTLES = 5
# WHERE BIN#=50;
# ```
# | BIN# | WINE | PRODUCER | YEAR | BOTTLES | READY|
# | --- | --- | --- | --- | --- | --- |
# | ... | ... | ... | ... | ... | ... |
# | 50 | Pinot Noir | Gary Farrel | 2000 | **5** | 2003 |

# %% [markdown]
# 4.
# ```SQL
# UPDATE CELLAR
# SET BOTTLES = BOTTLES+2
# WHERE BIN#=50;
# ```
# | BIN# | WINE | PRODUCER | YEAR | BOTTLES | READY|
# | --- | --- | --- | --- | --- | --- |
# | ... | ... | ... | ... | ... | ... |
# | 50 | Pinot Noir | Gary Farrel | 2000 | **5** | 2003 |

# %% [markdown]
# ### Напишите операторы на основе текста

# %% [markdown]
# ![вавфвыавыфыаывыаimage.png](attachment:image.png)

# %% [markdown]
# ![imваыфцфвуыафцвуыакage.png](attachment:image.png)

# %% [markdown]
# 1. Выбрать номер ячейки, наименование вина, количество бутылок для вин производства Geyser Peak
# ```SQL
# SELECT BIN#, WINE, BOTTLES
# FROM CELLAR
# WHERE PRODUCER = 'Geyser Peak';
# ```

# %% [markdown]
# 2. Выбрать номер ячейки, наименование вина, запас которых больше 5 бутылок
# ```SQL
# SELECT BIN#, WINE
# FROM CELLAR
# WHERE BOTTLES > 5;
# ```

# %% [markdown]
# 3. Выбрать номер ячейки для всех красных вин
# ```SQL
# SELECT BIN#
# FROM CELLAR
# WHERE WINE IN ('Cab. Savignon', 'Pinet Noir', 'Merlot', 'Zinfandel');
# ```

# %% [markdown]
# 4. Добавить 3 бутылки в ячейку 30.
# ```SQL
# UPDATE CELLAR
# SET BOTTLES = BOTTLES+3
# WHERE BIN# = 30;
# ```

# %% [markdown]
# 5. Удалить все вина Шардонэ.
# ```SQL
# DELETE
# FROM CELLAR
# WHERE PRODUCER = 'Chardonnay';
# ```

# %% [markdown]
# 6. Добавить новое поступление
# ```SQL
# INSERT
# INTO CELLAR (BIN#, WINE, PRODUCER, YEAR, BOTTLES, READY)f?
# VALUES (80, 'Merlot', 'Gary Farrel', 2000, 12, 2005);
# ```

# %% [markdown]
# ## Алан Болье. Изучаем SQL

# %% [markdown]
# ### Болье (гл. 3, Основы запросов) ✅

# %% [markdown]
# **УПРАЖНЕНИЕ 3.1**
#
# Получите идентификатор актера, а также имя и фамилию для всех актеров. Отсортируйте вывод сначала по фамилии, а затем — по имени.

# %% [markdown]
# ```sqlite
# SELECT actor_id, first_name, last_name
# FROM actor
# ORDER BY last_name, first_name
# ```

# %% [markdown]
# ![imfgddrfawdsfdawdesfrsedadbage.png](attachment:image.png)

# %% [markdown]
# **УПРАЖНЕНИЕ 3.2**
#
# Получите идентификатор, имя и фамилию актера для всех актеров, чьи фамилии — ' WILLIAMS ' или ' DAVIS '.

# %% [markdown]
# ```sqlite
# SELECT actor_id, first_name, last_name
# FROM actor
# ORDER BY last_name, first_name
# ```

# %% [markdown]
# ![уыавпеарнвкыуварпморспаывimage.png](attachment:image.png)

# %% [markdown]
# **УПРАЖНЕНИЕ 3.3**
#
# Напишите запрос к таблице ``rental``, который возвращает идентификаторы клиентов, бравших фильмы напрокат 5 июля 2005 года (используйте столбец ``rental.rental_date``; можете также использовать функцию ``date()``.

# %% [markdown]
# ```sqlite
# SELECT customer_id, rental_date
# FROM rental r
# WHERE date(r.rental_date)='2005-07-05';
# ```

# %% [markdown]
# ![imagedefrfewefsadsfdas.png](attachment:image.png)

# %% [markdown]
# **УПРАЖНЕНИЕ 3.4**
#
# Заполните пропущенные места (обозначенные как <#>) в следующем многотабличном запросе, чтобы получить показанные результаты:

# %% [markdown]
# ![ifsdgersrdgseawsfdgmage.png](attachment:image.png)

# %% [markdown]
# ```sqlite
# SELECT c.email, r.return_date
# FROM customer c
# 	INNER JOIN rental r
# 	ON c.customer_id = r.customer_id
# WHERE date(r.rental_date) = '2005-06-14'
# ORDER BY r.return_date DESC;
# ```

# %% [markdown]
# ![imaefsdgfesfdfdawdesfdge.png](attachment:image.png)

# %% [markdown]
# ### Болье (гл. 4, Фильтрация) ✅

# %% [markdown]
# **УПРАЖНЕНИЕ 4.1**
#
# *Какие из идентификаторов платежей будут возвращены при следующих условиях фильтрации?*

# %% [markdown]
# ```sqlite
# customer_id <> 5
# AND (amount > 8 OR date(payment_date) = '2005-08-23')
# ```

# %% [markdown]
# Вернуть такие индентификаторы клиента, что его id не равен 5.\
# И либо количество больше 8, либо дата платежа 2005-08-23

# %% [markdown]
# (Добавлены доп. столбцы для иллюстрации)

# %% [markdown]
# ```sqlite
# SELECT p.customer_id, date(payment_date), amount
# FROM payment p
# WHERE p.customer_id!=5 AND (p.amount>8 OR date(payment_date)='2005-08-2');
# ```

# %% [markdown]
# ![imaerdgfhdgrseasfre.png](attachment:image.png)

# %% [markdown]
# **УПРАЖНЕНИЕ 4.2**
# *Какие из идентификаторов платежей будут возвращены при следующих условиях фильтрации?*

# %% [markdown]
# ```sqlite
# customer_id = 5 AND
# NOT (amount > 6
#      OR date(payment_date) = '2005-06-19')
# ```

# %% [markdown]
# Вывести такие индикаторы платежей такие, что это был клиент с id=5, НО при это количество не более 6 И дата платежа не равна 2005-06-19.\
# Тут мной отрицание было раскрыто.

# %% [markdown]
# ![FASFDGBSFSXFESXFGSRimage.png](attachment:image.png)

# %% [markdown]
# **УПРАЖНЕНИЕ 4.3**
# *Создайте запрос, который извлекает из таблицы payments все строки, в которых сумма равна 1,98, 7,98 или 9,98.*

# %% [markdown]
# ```SQLITE
# SELECT *
# FROM payment
# WHERE amount IN (1.98, 7.98, 9.98);
# --OR
# SELECT *
# FROM payment
# WHERE (amount = 1.98 OR amount = 7.98 OR amount = 9.98);
# ```

# %% [markdown]
# ![iFSDDAFSAEFSAEWDSFDmage.png](attachment:image.png)

# %% [markdown]
# **УПРАЖНЕНИЕ 4.4**
# *Создайте запрос, который находит всех клиентов, в фамилиях которых содержатся буква А во второй позиции и буква W — в любом месте после А.*

# %% [markdown]
# ```SQLITE
# select *
# from customer c
# where last_name like '_A%W%';
# ```

# %% [markdown]
# ![iEWFRWESFEWmage.png](attachment:image.png)

# %% [markdown]
# ### Болье (гл. 5, Запросы к нескольким таблицам) ✅

# %% [markdown]
# **УПРАЖНЕНИЕ 5.1**
#
# Заполните пропущенные места (обозначенные как <# >) в следующем запросе так, чтобы получить показанные результаты:
# ```mysql
# SELECT с.first_name, c.last_name, a.address, ct.city
# INNER JOIN address <1>
# ON c.address_id = a.address_id
# INNER JOIN city ct
# ON a.city_id = <2>
# WHERE a.district = 'California';
# ```
# ![imfstgrfeesfdsesfdrage.png](attachment:image.png)

# %% [markdown]
# ```sql
# SELECT c.first_name, c.last_name, a.address, ct.city
# from customer c
# INNER JOIN address a
# ON c.address_id = a.address_id
# INNER JOIN city ct
# ON a.city_id = ct.city_id
# WHERE a.district = 'California';
# ```

# %% [markdown]
# ![idedfdawdsfsdwdasfdwedfdmage.png](attachment:image.png)

# %% [markdown]
# **УПРАЖНЕНИЕ 5.2**
#
# Напишите запрос, который выводил бы названия всех фильмов, в которых
# играл актер с именем JOHN.

# %% [markdown]
# ```mysql
# select a.first_name, f.title
# from actor a
# join film_actor fa on fa.actor_id=a.actor_id
# join film f on f.film_id=fa.film_id
# where a.first_name='john';
# ```

# %% [markdown]
# ![imfgdfeawsaesfdwazsfzage.png](attachment:image.png)

# %% [markdown]
# **УПРАЖНЕНИЕ 5.3**
#
# Создайте запрос, который возвращает все адреса в одном и том же городе.
# Вам нужно будет соединить таблицу адресов с самой собой, и каждая строка
# должна включать два разных адреса.

# %% [markdown]
# ```mysql
# select c.city, sh.address1, sh.address2
# from
# (select aa.address address1, a.address address2, a.city_id
# from address aa
# join address a on a.city_id=aa.city_id
# where a.address!=aa.address) sh
# join city c on c.city_id=sh.city_id;
# ```

# %% [markdown]
# ![imaefrgdtfdwdesfdxgwaesfrfefsge.png](attachment:image.png)

# %% [markdown]
# ### Болье (гл. 6, Работа с множествами) ✅

# %% [markdown]
# **УПРАЖНЕНИЕ 6.1**
#
# Пусть множество $А = {L,M,N,O,P}$, а множество $В = {P,Q,R,S,T}$. Какие множества будут сгенерированы следующими операциями?
# * ``A union В``
# * ``A union all В``
# * ``A intersect В``
# * ``A except В``

# %% [markdown]
# * $A\cup B=\{𝐿,𝑀,𝑁,𝑂,𝑃,𝑄,𝑅,𝑆,𝑇 \}$
# * $A\cup (ALL) B=\{𝐿,𝑀,𝑁,𝑂,𝑃, 𝑃,𝑄,𝑅,𝑆,𝑇 \}$
# * $A\cap B=\{𝑃\}$
# * $A  EXCEPT  B=\{𝐿,𝑀,𝑁,𝑂 \}$

# %% [markdown]
# **УПРАЖНЕНИЕ 6.2**
#
# Напишите составной запрос, который находит имена и фамилии всех актеров и клиентов, чьи фамилии начинаются с буквы L.

# %% [markdown]
# ```sql
# SELECT a.first_name, a.last_name
# FROM actor a
# WHERE a.last_name LIKE 'L%'
# UNION ALL
# SElect c.first_name, c.last_name
# from customer c
# WHERE c.last_name LIKE 'L%';
# ```

# %% [markdown]
# ![imadsfdsfdsfsdfsdf//'ge.png](attachment:image.png)

# %% [markdown]
# **УПРАЖНЕНИЕ 6.3**
#
# Отсортируйте результаты выполнения упражнения 6.2 по столбцу ``last_name``.

# %% [markdown]
# ```sql
# SELECT a.first_name, a.last_name
# FROM actor a
# WHERE a.last_name LIKE 'L%'
# UNION ALL
# SElect c.first_name, c.last_name
# from customer c
# WHERE c.last_name LIKE 'L%'
# order by last_name;
# ```

# %% [markdown]
# ![imasfdfdsfsdfsdfdsfsdfdsfsdfadssadadge.png](attachment:image.png)

# %% [markdown]
# ### Болье (гл. 7, Генерация, обработка и преобразование данных) ✅

# %% [markdown]
# **УПРАЖНЕНИЕ 7.1** \
# Напишите запрос, который возвращает символы строки 'Please find
# the substring in this string' с 17-го по 25-й.

# %% [markdown]
# ```mysql
# select substring('Please find the substring in this string', 17, 9);
# ```
# ![imfdfsawdsfseage.png](attachment:image.png)

# %% [markdown]
# **УПРАЖНЕНИЕ 7.2** \
# Напишите запрос, который возвращает абсолютное значение и знак
# (-1, 0 или 1) числа -25,76823. Верните также число, округленное до ближайших двух знаков после запятой.

# %% [markdown]
# ```mysql
# select abs(-25.76823), sign(-25.76823), round(-25.76823,2);
# ```
# ![imagedvgbbfedwsqDERH-2.png](attachment:image-2.png)

# %% [markdown]
# **УПРАЖНЕНИЕ 7.3** \
# Напишите запрос, возвращающий для текущей даты только часть, соответствующую месяцу.

# %% [markdown]
# ```MYSQL
# SELECT MONTH(curdate());
# ```
# ![imaWEFDWDERGEWQge.png](attachment:image.png)

# %% [markdown]
# ### Болье (гл. 8, Группировка и аргегация) ✅

# %% [markdown]
# **УПРАЖНЕНИЕ 8.1** \
# Создайте запрос, который подсчитывает количество строк в таблице
# payment.

# %% [markdown]
# ```mysql
# select count(*)
# from payment;
# ```
# ![imagsdsdgfdwassfdwdade.png](attachment:image.png)

# %% [markdown]
# **УПРАЖНЕНИЕ 8.2** \
# Измените запрос из упражнения 8.1 так, чтобы подсчитать количество
# платежей, произведенных каждым клиентом. Выведите идентификатор клиента и общую уплаченную сумму для каждого клиента.

# %% [markdown]
# ```mysql
# select customer_id, count(*), sum(amount)
# from payment
# group by customer_id;
# ```
# ![imwdesrdgbsedsfadsdage.png](attachment:image.png)

# %% [markdown]
# **УПРАЖНЕНИЕ 8.3** \
# Измените запрос из упражнения 8.2, включив в него только тех клиентов,
# у которых имеется не менее 40 выплат .

# %% [markdown]
# ```mysql
# select customer_id, count(*), sum(amount)
# from payment
# group by customer_id
# having count(*)>=40;
# ```
# ![imfdwaesfdesrdteage.png](attachment:image.png)

# %% [markdown]
# ### Болье (гл. 9, Подзапросы) ✅

# %% [markdown]
# **УПРАЖНЕНИЕ 9.1** \
# Создайте запрос к таблице ``film``, который использует условие фильтрации
# с некоррелированным подзапросом к таблице category, чтобы найти все боевики (``category.name = 'Action'``).

# %% [markdown]
# ```mysql
# select title
# FROM FILM
# where film_id in
# 	(select film_id from film_category where category_id=
# 		(select category_id from category where name='Action'));
# ```
# ```
# +---------------------+
# | # title             |
# +---------------------+
# | AMADEUS HOLY        |
# | AMERICAN CIRCUS     |
# | ANTITRUST TOMATOES  |
# | ARK RIDGEMONT       |
# | BAREFOOT MANCHURIAN |
# | ...                 |
# +---------------------+
# ```

# %% [markdown]
# **УПРАЖНЕНИЕ 9.2** \
# Переработайте запрос из упражнения 9.1, используя коррелированный подзапрос к таблицам ``category`` и ``film_category`` для получения тех же результатов.

# %% [markdown]
# ```mysql
# select title
# FROM FILM f
# where (select category_id from category where name='Action')=
# 	(select category_id from film_category fc where fc.film_id=f.film_id);
# ```
# ```
# +---------------------+
# | # title             |
# +---------------------+
# | AMADEUS HOLY        |
# | AMERICAN CIRCUS     |
# | ANTITRUST TOMATOES  |
# | ARK RIDGEMONT       |
# | BAREFOOT MANCHURIAN |
# | ...                 |
# +---------------------+
# ```
# ```MYSQL
# -- лучше некореллированное решение
# SELECT f.title
# FROM film f
# WHERE EXISTS
# (SELECT 1
# FROM film_category fc
# INNER JOIN category c ON fc.category_id = c.category_id
# WHERE c.name = 'Action'
# AND fc.film_id = f.film_id);
# ```

# %% [markdown]
# **УПРАЖНЕНИЕ 8.3** \
# Соедините следующий запрос с подзапросом к таблице film_actor, чтобы показать уровень мастерства каждого актера:
# ```mysql
# SELECT 'Hollywood Star' level, 30 min_roles, 99999 max_roles
# UNION ALL
# SELECT 'Prolific Actor' level, 20 min_roles, 29 max_roles
# UNION ALL
# SELECT 'Newcomer' level, 1 min roles, 19 max roles
# ```
# Подзапрос к таблице film_actor должен подсчитывать количество строк
# для каждого актера с использованием group by actor_id, и результат подсчета должен сравниваться со столбцами min_roles/max_roles, чтобы определить, какой уровень мастерства имеет каждый актер.

# %% [markdown]
# ```mysql
# select actr.actor_id, num_roles, grps.level
# from
# (select actor_id, count(*) num_roles
# from film_actor
# group by actor_id) as actr
# inner join
# (SELECT 'Hollywood Star' level, 30 min_roles, 99999 max_roles
# UNION ALL
# SELECT 'Prolific Actor' level, 20 min_roles, 29 max_roles
# UNION ALL
# SELECT 'Newcomer' level, 1 min_roles, 19 max_roles) as grps
# on actr.num_roles between  grps.min_roles AND grps.max_roles;
# ```
# ```
# +------------+-----------+----------------+
# | # actor_id | num_roles | level          |
# +------------+-----------+----------------+
# | 1          | 19        | Newcomer       |
# | 2          | 25        | Prolific Actor |
# | 3          | 22        | Prolific Actor |
# | 4          | 23        | Prolific Actor |
# | 5          | 29        | Prolific Actor |
# | 6          | 20        | Prolific Actor |
# | 7          | 30        | Hollywood Star |
# +------------+-----------+----------------+
# ```

# %% [markdown]
# ### Болье (гл. 10, Соединения) ✅

# %% [markdown]
# **УПРАЖНЕНИЕ 10.1** \
# Используя следующие определения таблиц и данные, напишите запрос, который возвращает имя каждого клиента вместе с его суммами платежей:
# ![imagвыавпаывыавыe.png](attachment:image.png)
# Включите в результирующий набор всех клиентов, даже если для клиента
# нет записей о платежах.

# %% [markdown]
# ```mysql
# SELECT c.customer_id, concat(c.first_name,' ', c.last_name) name, SUM(p.amount)
# from customer c
# left OUTER join payment p on p.customer_id=c.customer_id
# group by c.customer_id;
# ```
# ![ifsddfsdafdasfdsamage.png](attachment:image.png)

# %% [markdown]
# **УПРАЖНЕНИЕ 10.2** \
# Измените запрос из упражнения 10.1 таким образом, чтобы использовать другой тип внешнего соединения (например, если вы использовали левое внешнее соединение в упражнении 10.1, на этот раз используйте правое
# внешнее соединение) так, чтобы результаты были идентичны полученным
# ранее.

# %% [markdown]
# ```mysql
# SELECT c.customer_id, concat(c.first_name,' ', c.last_name) name, SUM(p.amount)
# from payment p
# right OUTER join customer c on p.customer_id=c.customer_id
# group by c.customer_id;
# ```
# ![imadsffdfasfadfadfadfgsegthfgbdvge.png](attachment:image.png)

# %% [markdown]
# **УПРАЖНЕНИЕ 10.3** \
# Разработайте запрос, который будет генерировать набор {1, 2, 3, ..., 99,
# 100}. (Указание: используйте перекрестное соединение как минимум с двумя
# подзапросами в предложении from.)

# %% [markdown]
# ```mysql
# SELECT ones.x + tens.x + 1
# FROM
# (SELECT 0 x UNION ALL
# SELECT 1 x UNION ALL
# SELECT 2 x UNION ALL
# SELECT 3 x UNION ALL
# SELECT 4 x UNION ALL
# SELECT 5 x UNION ALL
# SELECT 6 x UNION ALL
# SELECT 7 x UNION ALL
# SELECT 8 x UNION ALL
# SELECT 9 x
# ) ones
# CROSS JOIN
# (SELECT 0 x UNION ALL
# SELECT 10 x UNION ALL
# SELECT 20 x UNION ALL
# SELECT 30 x UNION ALL
# SELECT 40 x UNION ALL
# SELECT 50 x UNION ALL
# SELECT 60 x UNION ALL
# SELECT 70 x UNION ALL
# SELECT 80 x UNION ALL
# SELECT 90 x
# ) tens;
# ```
# ![imaggvhbjnkmlhbgbhne.png](attachment:image.png)

# %% [markdown]
# ### Болье (гл. 11, Условная логика) ✅

# %% [markdown]
# **УПРАЖНЕНИЕ 11.1** \
# Перепишите следующий запрос, в котором используется простое выражение case, так, чтобы получить те же результаты с использованием поискового выражения case. Старайтесь, насколько это возможно, использовать как
# можно меньше предложений when.
# ```mysql
# SELECT namе,
# CASE name
#     WHEN 'English' THEN 'latin1'
#     WHEN 'Italian' THEN 'latin1'
#     WHEN 'French' THEN 'latin1'
#     WHEN 'German' THEN 'latin1'
#     WHEN 'Japanese' THEN 'utf8'
#     WHEN 'Mandarin' THEN 'utf8'
#     ELSE 'Unknown'
# END character_set
# FROM language;
# ```

# %% [markdown]
# *Решение*
# ```mysql
# select name,
# case
# 	when name in ('English', 'Italian', 'French', 'German') then 'latin1'
#     when name in ('Japanese', 'Mandarin') then 'utf8'
#     else 'Unknown'
#     end character_set
# from language;
# ```
# ![imagwdefgbredwsdrfgnrewe.png](attachment:image.png)

# %% [markdown]
# **УПРАЖНЕНИЕ 11.1** \
# Перепишите следующий запрос так, чтобы результирующий набор содержал одну строку с пятью столбцами (по одному для каждого рейтинга). Назовите эти пять столбцов G, PG, PG_13, R и NC_17.
# ```mysql
# SELECT rating, count(*)
# FROM film
# GROUP BY rating;
# ```
# ![iwerdfgbfedqwdertgrfedwdfgmage.png](attachment:image.png)

# %% [markdown]
# ```MYSQL
# SELECT
# SUM(case when rating='G' THEN 1 ELSE 0 END) G,
# SUM(case when rating='PG' THEN 1 ELSE 0 END) PG,
# SUM(case when rating='PG-13' THEN 1 ELSE 0 END) PG_13,
# SUM(case when rating='R' THEN 1 ELSE 0 END) R,
# SUM(case when rating='NC-17' THEN 1 ELSE 0 END) NC_17
# FROM film;
# ```
# ![imWDFDQADSFDAWDSFage.png](attachment:image.png)

# %% [markdown]
# ### Болье (гл. 12, Транзакции) ✅

# %% [markdown]
# **УПРАЖНЕНИЕ 12.1** \
# Создайте логическую единицу работы для перевода 50 долларов со счета
# 123 на счет 789. Для этого вставьте две строки в таблицу ``transaction`` и обновите две строки в таблице ``account``. Используйте следующие определения
# данные таблиц:
# ![imdfsfdfddasfddsfage.png](attachment:image.png)
# Используйте ``txn_type_cd = 'С'``, чтобы указать операцию кредита (добавление на счет ), и ``txn_type_cd ='D'`` для обозначения дебета (снятия со счета).

# %% [markdown]
# ```mysql
# -- ЭТО ПСЕВДОКОД!
# START TRANSACTION;
# -- запись транзакции
# INSERT INTO transaction (txn_id, txn_date, account_id, txn_type_cd, amount)
# VALUES
# (NULL, NOW(), 123, 'D', 50),
# (NULL, NOW(), 789, 'C', 50);
#
# /* Перевод с первого счета на второй */
# -- снятие
# UPDATE account
# SET avail_balance = avail_balance - 50,
# last_activity = now()
# WHERE account_id = 123
# AND avail_balance > 50;
# -- перевод
# UPDATE account
# SET avail_balance = avail_balance + 50,
# last_activity = now()
# WHERE account_id = 789;
#
# COMMIT;
# ```

# %% [markdown]
# ## К. Дж. Дейт. SQL и реляционная теория (гл. 1. Введение)

# %% [markdown]
# ![imdsfdsfdsfsdfsdfsage.png](attachment:image.png)

# %% [markdown]
# ![idafsgdtsaeEAESFAEmage.png](attachment:image.png)

# %% [markdown]
# ## В.М. Стасышин, Т.Л. Стасышина "Практикум по языку SQL"
# (Лабораторные работы)

# %% [markdown]
# file:///C:/Users/79618/Desktop/%D0%9D%D0%B5%D0%BE%D1%82%D1%81%D0%BE%D1%80%D1%82%20SQL/%D0%A1%D1%82%D0%B0%D1%81%D1%8B%D1%88%D0%B8%D0%BD%20%D0%92.%D0%9C.,%20%D0%A1%D1%82%D0%B0%D1%81%D1%8B%D1%88%D0%B8%D0%BD%D0%B0%20%D0%9B.%D0%A2.%20-%20%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D0%BA%D1%83%D0%BC%20%D0%BF%D0%BE%20%D1%8F%D0%B7%D1%8B%D0%BA%D1%83%20SQL_%20%D1%83%D1%87%D0%B5%D0%B1%D0%BD%D0%BE%D0%B5%20%D0%BF%D0%BE%D1%81%D0%BE%D0%B1%D0%B8%D0%B5-%D0%AD%D0%91%D0%A1%20%D0%9B%D0%B0%D0%BD%D1%8C%20(2016).pdf

# %% [markdown]
# ### Создание таблицы для лабораторных работ

# %% [markdown]
# ```sqlite
# --0. СОЗДАНИЕ ТАБЛИЦ
# CREATE TABLE suppliers
# (post_id INTEGER PRIMARY KEY AUTOINCREMENT,
# name VARCHAR(20),
# rating INTEGER,
# town varchar(20));
#
# CREATE TABLE parts
# (det_id INTEGER PRIMARY KEY AUTOINCREMENT,
# name VARCHAR(20),
# color VARCHAR(20),
# rating INTEGER,
# town varchar(20));
#
# CREATE TABLE products
# (izd_id INTEGER PRIMARY KEY AUTOINCREMENT,
# name VARCHAR(20),
# town varchar(20));
#
# drop table shipments;
# CREATE TABLE shipments
# (ship_id INTEGER PRIMARY KEY AUTOINCREMENT,
# post_id INTEGER,
# det_id INTEGER,
# izd_id INTEGER,
# amount INTEGER
# REFERENCES suppliers (post_id)
# REFERENCES parts (det_id)
# REFERENCES products (izd_id));
#
# INSERT INTO shipments
# values
# (null, 1, 1, 1, 200),
# (null, 1, 1, 4, 700),
# (null, 2, 3, 1, 400),
# (null, 2, 3, 2, 200),
# (null, 2, 3, 3, 200),
# (null, 2, 3, 4, 500),
# (null, 2, 3, 5, 600),
# (null, 2, 3, 6, 400),
# (null, 2, 3, 7, 800),
# (null, 2, 5, 2, 100),
# (null, 3, 3, 1, 200),
# (null, 3, 4, 2, 500),
# (null, 4, 6, 3, 300),
# (null, 4, 6, 7, 300),
# (null, 5, 2, 2, 200),
# (null, 5, 2, 4, 100),
# (null, 5, 5, 5, 500),
# (null, 5, 5, 7, 100),
# (null, 5, 6, 2, 200),
# (null, 5, 1, 4, 100),
# (null, 5, 3, 4, 200),
# (null, 5, 4, 4, 800),
# (null, 5, 5, 4, 400),
# (null, 5, 6, 4, 500);
#
# INSERT INTO suppliers
# values
# (null, 'Смит', 20, 'Лондон'),
# (null, 'Джонс', 10, 'Париж'),
# (null, 'Блейк', 30, 'Париж'),
# (null, 'Кларк', 20, 'Лондон'),
# (null, 'Адамс', 30, 'Афины');
#
# INSERT INTO parts
# values
# (null,'Гайка', 'Красный', 12, 'Лондон'),
# (null,'Болт', 'Зеленый', 17, 'Париж'),
# (null,'Винт', 'Голубой', 17, 'Рим'),
# (null,'Винт', 'Красный', 14, 'Лондон'),
# (null,'Кулачок', 'Голубой', 12, 'Париж'),
# (null,'Блюм', 'Красный', 19, 'Лондон');
#
# INSERT INTO products
# values
# (null, 'Жесткий диск', 'Париж'),
# (null, 'Перфоратор', 'Рим'),
# (null, 'Считыватель', 'Афины'),
# (null, 'Принтер', 'Афины'),
# (null, 'Флоппи-диск', 'Лондон'),
# (null, 'Терминал', 'Осло'),
# (null, 'Лента', 'Лондон');
# -------------------------------------------------
# --Жаргон
# --Число поставок…. == число строк таблицы spj ….
# --Объем поставки == количество поставленных деталей == значение столбца kol таблицы spj.
# --Количество деталей …. == количество поставленных деталей == значение столбца kol таблицы spj.
# --Вес поставки == количество поставленных деталей * вес поставленной детали (вес, указанный в таблице p, – это вес одной детали).
# --Число деталей …. == число разных номеров (наименований, видов, типов) деталей….
# --Число изделий …. == число разных номеров (наименований, видов, типов) изделий ….
# --Число поставщиков …. == число разных номеров (наименований, видов, типов) поставщиков ….
# --Город, из которого сделана поставка, == город, где производится деталь, указанная в поставке.
# --Город, куда сделана поставка, == город, где собирают изделие, указанное в поставке.
# ```

# %% [markdown]
# ### ПРИМЕР 1 (Лабораторная работа 2 – задание 2)
# Найти поставщиков, которые поставляли детали красного
# цвета для изделий с длиной названия >8. Вывести номера поставщиков без повторений в порядке возрастания номеров.

# %% [markdown]
# ```sql
# select DISTINCT post_name, post_id
# from
# (select sh.*, p.color, s.name post_name, length(pr.name) len_name, pr.name izd_name,
# s.post_id post_id
# from shipments sh
# join parts p on p.det_id=sh.det_id
# join suppliers s on s.post_id=sh.post_id
# join products pr on pr.izd_id=sh.izd_id
# where len_name>8 and color='Красный')
# order by 2;
# ```

# %% [markdown]
# ![imagdsfdadasfdase.png](attachment:image.png)

# %% [markdown]
# 1. **Вывести о каждой поставке информацию:**
# - город, откуда сделана поставка;
# - город, куда поставлены детали;
# - количество деталей;
# - вес детали.

# %% [markdown]
# ```sql
# select sh.ship_id,sh.amount, p.town town_from, pr.town town_to, p.weight
# FROM shipments sh
# join parts p on p.det_id=sh.det_id
# join products pr on pr.izd_id=sh.izd_id;
# ```

# %% [markdown]
# 2. **Вывести без повторений пары цвет детали – город, куда поставлена деталь.**

# %% [markdown]
# ```sql
# select distinct p.color, pr.town
# from shipments sh
# join parts p on p.det_id=sh.det_id
# join products pr on pr.izd_id=sh.izd_id;
# ```

# %% [markdown]
# ![imdfssafsdfsdasage.png](attachment:image.png)

# %% [markdown]
# ### ПРИМЕР 2 (Лабораторная работа 4 – задание 1)
# Выдать число изделий, для которых поставлялись детали из
# города, где проживает поставщик с максимальным рейтингом.

# %% [markdown]
# ```mysql
# -- города поставщиков с максимальным рейтингом
# select town
# from suppliers
# where rating in (select max(rating)
# from suppliers);
# ```
# ![imdwfrrdewsdsqsweage.png](attachment:image.png)

# %% [markdown]
# ```mysql
# -- Выведем информацию о поставках и деталях из тех городов, где поставщики имеют максимальный рейтинг
# select *
# from shipments sh
# join parts p on p.det_id=sh.det_id
# where p.town in (select town
# from suppliers
# where rating in (select max(rating)
# from suppliers));
# ```
# ![efswqdefxfdwqdesrimage.png](attachment:image.png)

# %% [markdown]
# ```mysql
# -- Окончательный запрос: # РАЗЛИЧНЫХ id изделий
# select count(distinct sh.izd_id)
# from shipments sh
# join parts p on p.det_id=sh.det_id
# where p.town in (select town
# from suppliers
# where rating in (select max(rating)
# from suppliers));
# ```
# ![imagesfdgfsawdsfrswadsfce.png](attachment:image.png)

# %% [markdown]
# **ДЗ: Определить средний вес поставки в город, где производят изделие с самым длинным названием.**

# %% [markdown]
# ```MYsql
# -- самое длинное название изделия
# select max(length(name))
# from products;
# ```

# %% [markdown]
# ![imfddevfedfvfddsddsdsage.png](attachment:image.png)

# %% [markdown]
# ```sql
# -- город, где производится изделие с самым длинным названием
# select town from products
# where length(name) in (select max(length(name)) from products);
# ```

# %% [markdown]
# ![im mknjjkonhjkvfndnemjfvhiejfew324432age.png](attachment:image.png)

# %% [markdown]
# ```sql
# select sh.*, pr.town, p.weight from shipments sh
# join parts p on p.det_id=sh.det_id
# join products pr on pr.izd_id=sh.izd_id
# where pr.town in
# (select town from products
# where length(name) in (select max(length(name)) from products));
# ```

# %% [markdown]
# ![imagjikojnkjnikjnkjnkoe.png](attachment:image.png)

# %% [markdown]
# ```MYsql
# -- Окончательное решение
# select avg(p.weight*sh.amount) from shipments sh
# join parts p on p.det_id=sh.det_id
# join products pr on pr.izd_id=sh.izd_id
# where pr.town in
# (select town from products
# where CHAR_LENGTH(name) in (select max(CHAR_LENGTH(name)) from products));
# ```
# ![imWDSDFADSDADSage.png](attachment:image.png)

# %% [markdown]
# ### ПРИМЕР 3 (Лабораторная работа 2 – задание 1)
# Выбрать изделия, для которых поставлялись красные детали,
# поставлявшиеся для изделия c названием длиной больше 11.

# %% [markdown]
# ```mysql
# -- изделия с длиной названия больше 11
# select *, CHAR_LENGTH(TRIM(name))
# from products
# where CHAR_LENGTH(TRIM(name))>11;
# ```
# ![imWEEFRGEFEQWDEFWDage.png](attachment:image.png)

# %% [markdown]
# ```mysql
# -- Красные детали
# select *
# from parts
# where color='Красный';
# ```
# ![imWDEDRFDWDFDFSDAage.png](attachment:image.png)

# %% [markdown]
# ```mysql
# -- Детали, поставлявшиеся для изделий с именем длины >11.
# select distinct sh.det_id
# from shipments sh
# join products pr on pr.izd_id=sh.izd_id
# where char_length(TRIM(pr.name))>11;
# ```
# ![imaDWEFEDWQSADSADSge.png](attachment:image.png)

# %% [markdown]
# ```mysql
# -- Красные детали, поставлявшиеся для изделий с именем длины >11.
# select sh.det_id
# from shipments sh
# join products pr on pr.izd_id=sh.izd_id
# JOIN parts p on p.det_id=sh.det_id
# where char_length(TRIM(pr.name))>11
# and p.color='Красный';
# ```
# ![imXFDSdXFFZEFXFZXCage.png](attachment:image.png)

# %% [markdown]
# ```mysql
# -- Окончательный ответ
# select distinct t.izd_id
# from shipments t
# where t.det_id in
# (select sh.det_id
# from shipments sh
# join products pr on pr.izd_id=sh.izd_id
# JOIN parts p on p.det_id=sh.det_id
# where char_length(TRIM(pr.name))>11
# and p.color='Красный');
# ```
# ![iDFDSQADSDSSWDSmage.png](attachment:image.png)

# %% [markdown]
# **ДЗ: Выбрать поставщиков, которые поставляли детали с весом > 17, поставлявшиеся для изделий из Афин.**

# %% [markdown]
# ```mysql
# -- поставки деталей весом>17
# select *
# from shipments sh
# join parts p on p.det_id=sh.det_id
# where p.weight>17;
# ```
# ![imaDEDSQSWDSDDSDWQDge.png](attachment:image.png)

# %% [markdown]
# ```MYSQL
# -- Изделия из Афин
# select izd_id
# from products
# where town='Афины';
# -- Детали поставлявшиеся для изделий из афин
# select distinct post_id
# from shipments sh
# join products pr on pr.izd_id=sh.det_id
# join parts p on p.det_id=sh.det_id
# where pr.town='Афины' and
# post_id in (select distinct post_id
# from shipments sh
# join products pr on pr.izd_id=sh.det_id
# join parts p on p.det_id=sh.det_id
# where weight>17);
# ```
# ![iEFDSQASDSWDSmage.png](attachment:image.png)

# %% [markdown]
# ### ПРИМЕР 4 (Лабораторная работа 4 – задание 1)
# Выдать число деталей, поставлявшихся поставщиками,
# проживающими в городе, где собирают изделие с буквой «ф»
# в названии.

# %% [markdown]
# ```MYSQL
# -- Города где собирают изделия с буквой "ф"
# select *
# from products
# where lower(name) like '%ф%';
# ```
# ![iWESFADWADSFDASFDADFSmage.png](attachment:image.png)

# %% [markdown]
# ```MYSQL
# -- Поставщики из города, где собирают изделие с буквой "ф"
# select *
# from suppliers s
# where s.town in
# (select pr.town
# from products pr
# where lower(pr.name) like '%ф%');
# ```
# ![imaESDSasfdWADSFge.png](attachment:image.png)

# %% [markdown]
# ```MYSQL
# -- Поставки от этих поставщиков
# select *
# from shipments
# where post_id in
# (select post_id
# from suppliers
# where post_id in
# (select s.post_id
# from suppliers s
# where s.town in
# (select p.town
# from products p
# where lower(p.name) like '%ф%')));
# ```
# ![imaDESFDGFDWASFDge.png](attachment:image.png)

# %% [markdown]
# ```MYSQL
# select count(distinct det_id)
# from shipments
# where post_id in
# (select post_id
# from suppliers
# where post_id in
# (select s.post_id
# from suppliers s
# where s.town in
# (select p.town
# from products p
# where lower(p.name) like '%ф%')));
# ```
# ![imaSADSVDSWDSDSge.png](attachment:image.png)

# %% [markdown]
# **ДЗ: Выдать число городов, в которые выполняли поставки поставщики, поставлявшие какую-либо зеленую деталь.**

# %% [markdown]
# ```MYSQL
# -- Зеленые детали
# select *
# from parts
# where color='Зеленый';
# ```
# ![rsfsSASVDSWADDGF.png](attachment:image.png)

# %% [markdown]
# ```MYSQL
# -- Поставки зеленых деталей (только 1 поставщик зеленых деталей)
# select count(distinct pr.town)
# from shipments sh
# join parts p on p.det_id=sh.det_id
# join products pr on pr.izd_id=sh.izd_id
# where p.color='Зеленый';
# ```
# ![imagDSwadeqAESRDWAESRe.png](attachment:image.png)

# %% [markdown]
# ### ПРИМЕР 5 (Лабораторная работа 2 – задание 5)
# Построить таблицу со списком городов таких, что в городе
# вместе с поставщиком размещаются либо только детали, либо
# только изделия, но не то и другое вместе.

# %% [markdown]
# ```MYSQL
# -- города поставщиков и деталями
# SELECT distinct town FROM SUPPLIERS
# where town in (select town from parts);
# ```
# ![imawdeferwdfeewqege.png](attachment:image.png)

# %% [markdown]
# ```mysql
# -- города поставщиков и изделий
# SELECT distinct town FROM SUPPLIERS
# where town in (select town from products);
# ```
# ![imwdrdfwqdfdfewqdfage.png](attachment:image.png)

# %% [markdown]
# ```mysql
# -- города поставщиков + деталей + изделий
# SELECT distinct town FROM SUPPLIERS
# where town in (select town from parts where town in (select town from products));
# ```
# ![imweftgewsdefdfdfdwadsdage.png](attachment:image.png)

# %% [markdown]
# ```mysql
# -- окончательное решение
# select * from
# (SELECT distinct town FROM SUPPLIERS
# where town in (select town from parts)
# union all
# SELECT distinct town FROM SUPPLIERS
# where town in (select town from products)) x
# where town not in (SELECT distinct town FROM SUPPLIERS
# where town in (select town from parts where town in (select town from products)));
# ```
# ![image-2wdevdssadvfdsadvcv.png](attachment:image-2.png)

# %% [markdown]
# **ДЗ**: *Построить таблицу с упорядоченным списком городов таких, что
# в городе размещается более одного поставщика и производится какая-либо деталь, но не собирается ни одно изделие.* \
# *Измените данные таким образом, чтобы запрос давал другой результат.*

# %% [markdown]
# ```MYSQL
# -- города с 2мя поставщиками
# SELECT town
# FROM SUPPLIERS
# group by town
# having COUNT(POST_ID)>1;
# ```
# ![imadfddwqDASFEDWAESFEWESge.png](attachment:image.png)

# %% [markdown]
# ```MYSQL
# -- ОКОНЧАТЕЛЬНОЕ РЕШЕНИЕ
# select distinct town
# from suppliers
# where town in
# (SELECT town
# FROM SUPPLIERS
# group by town
# having COUNT(POST_ID)>1)
# and
# town in
# (select town from parts)
# and town not in (select town from products);
# ```
# *Пустое множество*

# %% [markdown]
# ![уаывпкуцФУВПКУЫКВПЕimage.png](attachment:image.png)

# %% [markdown]
# ### ПРИМЕР 6 (Лабораторная работа 2 – задание 3)
# Получить список деталей, которые поставляли ТОЛЬКО поставщики, выполнившие поставки в Рим.

# %% [markdown]
# ```MYSQL
#
# ```

# %% [markdown]
# ```MYSQL
#
# ```

# %% [markdown]
# ```MYSQL
#
# ```

# %% [markdown]
# ```MYSQL
#
# ```

# %% [markdown]
# ```MYSQL
#
# ```

# %% [markdown]
# ```MYSQL
#
# ```

# %% [markdown]
# ```MYSQL
#
# ```

# %% [markdown]
# **ДЗ: Получить список изделий, для которых выполнили поставки
# ТОЛЬКО поставщики, поставлявшие детали из Парижа.**

# %% [markdown]
# ### ПРИМЕР 7 (Лабораторная работа 4 – задание 5)
# Выдать полную информацию о деталях, которые поставлялись
# ТОЛЬКО для изделий с числом поставок не менее 5.

# %% [markdown]
# **ДЗ: Получить список поставщиков, которые поставляли ТОЛЬКО те
# детали, которые поставлялись для трех и более изделий.**

# %% [markdown]
# ### ПРИМЕР 8 (Лабораторная работа 2 – задание 4)
# Вывести полный список городов и для каждого города найти
# общий вес деталей красного цвета, поставленных в этот город.
# Города в списке должны быть ВСЕ. Список должен быть упорядочен по алфавиту.

# %% [markdown]
# **ДЗ: Вывести полный список поставщиков и для каждого поставщика
# определить, детали скольких разных цветов были им поставлены для
# изделия J4. Поставщики в списке должны быть ВСЕ. Список должен
# быть упорядочен по номеру.**

# %% [markdown]
# ### ПРИМЕР 9 (Лабораторная работа 6 – задание 3)
# Для каждой детали вывести ее номер и средний объем поставок этой детали поставщиком S2 или 0, если поставок не было.
# Детали в списке должны быть ВСЕ. Список должен быть упорядочен по номеру детали

# %% [markdown]
# **ДЗ: Для каждой детали определить, сколько поставщиков поставляли
# эту деталь для изделий с длиной названия меньше 7. Детали в списке
# должны быть ВСЕ. Список должен быть упорядочен по номеру детали.**

# %% [markdown]
# ### ПРИМЕР 10 (Лабораторная работа 5 – задание 1)
# Получить средний вес поставки для каждого изделия и найти
# их среднее.

# %% [markdown]
# **ДЗ: Получить число поставок для каждой детали и найти их среднее.**

# %% [markdown]
# ### ПРИМЕР 11 (Лабораторная работа 2 – задание 6)
# Каждое изделие, в названии которого есть буква «к», перевести
# в город, в котором проживает поставщик, сделавший для изделия
# наименьшую по объему поставку. Если таких городов больше одного, перевести в первый по алфавиту из этих городов

# %% [markdown]
# **ДЗ: Каждую красную деталь перевести в город, в котором проживает поставщик, сделавший наибольшую по весу поставку этой детали.
# Если таких городов больше одного, перевести в первый по алфавиту
# из этих городов.**

# %% [markdown]
# ### ПРИМЕР 12 (Лабораторная работа 3 – задание 2)
# Получить номера изделий, для которых поставлялась КАЖДАЯ
# деталь из списка поставщика S2.

# %% [markdown]
# **ДЗ: Выдать номера изделий, детали для которых поставляет каждый
# поставщик, поставляющий какую-либо красную деталь**

# %% [markdown]
# ### ПРИМЕР 13 (Лабораторная работа 4 – задание 2)
# Поменять местами города, где проживают поставщики с минимальным и максимальным рейтингом, т. е. поставщиков с минимальным рейтингом перевести в город, где проживает поставщик с максимальным рейтингом, и наоборот, поставщиков с
# максимальным рейтингом перевести в город, где проживает поставщик с минимальным рейтингом. Если городов несколько,
# брать первый по алфавиту из этих городов.

# %% [markdown]
# **ДЗ: Поменять местами рейтинги первого и последнего по алфавиту
# поставщиков.**

# %% [markdown]
# ### ПРИМЕР 14 (Лабораторная работа 4 – задание 4)
# Выбрать города, в которые не делал поставок ни один поставщик, поставлявший зеленые детали.

# %% [markdown]
# **ДЗ: Выбрать детали, не поставлявшиеся ни для одного из изделий, для
# которых поставлял детали поставщик S3.**

# %% [markdown]
# ### ПРИМЕР 15 (Лабораторная работа 4 – задание 3)
# Найти поставщиков, имеющих поставки, вес которых составляет менее 20 % от максимального веса поставки красной детали,
# выполненной этим поставщиком. Вывести номер поставщика, вес
# поставки, максимальный вес поставки красной детали, сделанной
# поставщиком.

# %% [markdown]
# **ДЗ: Найти изделия, имеющие поставки, объем которых в 8 раз меньше
# объема наибольшей поставки для изделия. Вывести номер изделия,
# объем поставки, объем наибольшей поставки для изделия**

# %% [markdown]
# ### ПРИМЕР 16 (Лабораторная работа 5 – задание 2)
# Для каждого поставщика из Парижа найти число поставок
# каждой детали, им поставлявшейся. Вывести номер поставщика,
# город поставщика, номер детали, название детали, число поставок.

# %% [markdown]
# **ДЗ: Для каждой детали из Лондона найти максимальный объем поставки этой детали каждым поставщиком, ее поставлявшим. Вывести номер детали, город детали, номер поставщика, фамилию поставщика, максимальный объем поставки детали поставщиком.**

# %% [markdown]
# ### ПРИМЕР 17 (Лабораторная работа 5 – задание 3)
# Найти города поставщиков, поставлявших деталь P1, и определить, какой процент составляет суммарный вес поставок поставщиками из каждого города от общего веса поставленных деталей P1. Вывести город, суммарный вес поставок поставщиков из
# этого города, общий вес поставленных деталей P1, процент.

# %% [markdown]
# **ДЗ 1: Найти детали, которые поставлял поставщик S4, и определить, какой процент составляет суммарный вес поставок каждой
# детали от общего веса деталей, поставленных S4. Вывести номер
# детали, суммарный вес поставок этой детали, общий вес деталей поставщика S4, процент.**

# %% [markdown]
# **ДЗ 2: Найти изделия, для которых поставлял детали поставщик S2,
# и определить, какой процент составляют поставки для каждого изделия от общего числа поставок S2. Вывести номер изделия, число
# поставок для этого изделия, общее число поставок поставщика S2,
# процент.**

# %% [markdown]
# ```mysql
#
# ```

# %% [markdown]
# ```mysql
#
# ```

# %% [markdown]
# ```mysql
#
# ```

# %% [markdown]
# ```mysql
#
# ```

# %% [markdown]
# ```mysql
#
# ```

# %% [markdown]
# ```mysql
#
# ```

# %% [markdown]
# ## Chinook queries ✅

# %% [markdown]
# * [Ответы](https://github.com/LucasMcL/15-sql_queries_02-chinook/blob/master/chinook-queries.sql)
# * [Задания](http://www.berkut.mk.ua/download/pdf/db/task_vesna.pdf)

# %% [markdown]
# **Task # 1: Prerequisites**
#
#
# 1. Download Chinook Database script for yours DBMS. Use this [link](https://github.com/lerocha/chinook-database) for Chinook repository
# 2. Install it
# 3. Build an ERD
# 4. Write report with info about tables (names and types of columns and number of rows in each)

# %% [markdown]
# **Task # 2: Query Practice (part 1)**
#
# Use the Chinook Database and the DB Browser for your Database Server
# For each of the following exercises, provide the appropriate query (or some queries).
# Obviously provide results for each query!

# %% [markdown]
# 1. Provide a query showing Customers (just their full names, customer ID and country) who are not in the US.
# ```MYSQL
# select CustomerId, concat(FirstName, ' ', LastName) fullname, Country
# from customer
# where Country!='USA'
# ```

# %% [markdown]
# 2. Provide a query only showing the Customers from Brazil.
# ```mysql
# select *
# from customer
# where Country='Brazil';
# ```

# %% [markdown]
# 3. Provide a query showing the Invoices of customers who are from Brazil. The resultant table should show the customer’s full name, Invoice ID, Date of the invoice and billing country.
# ```mysql
# select concat(c.FirstName, ' ', c.LastName) fullname,i.InvoiceId, i.InvoiceDate, i.BillingCountry
# from invoice i
# left join customer c on c.CustomerId=i.CustomerId
# where c.Country='Brazil';
# ```

# %% [markdown]
# 4. Provide a query showing only the Employees who are Sales Agents.
# ```mysql
# select *
# from employee
# where title='Sales Support Agent';
# ```

# %% [markdown]
# 5. Provide a query showing a unique list of billing countries from the Invoice table.
# ```mysql
# select distinct BillingCountry
# from invoice;
# ```

# %% [markdown]
# 6. Provide a query that shows the invoices associated with each sales agent. The resultant table should include the Sales Agent’s full name.
# ```mysql
# select concat(e.FirstName, ' ', e.LastName) agents_fullname, i.*
# from customer c
# join employee e on c.SupportRepId=e.EmployeeId
# join invoice i on i.CustomerId=c.CustomerId;
# ```

# %% [markdown]
# 7. Provide a query that shows the Invoice Total, Customer name, Country and Sale Agent name for all invoices and customers.
# ```mysql
# select e.firstname, e.lastname, i.invoiceid, i.customerid, i.invoicedate, i.billingaddress, i.billingcountry, i.billingpostalcode, i.total
# from customer as c, invoice as i
# on c.customerid = i.customerid
# join employee as e
# on e.employeeid = c.supportrepid
# order by e.employeeid;
# ```

# %% [markdown]
# 8. How many Invoices were there in 2009 and 2011? What are the respective total sales for each of those years?
# ```mysql
# select year(InvoiceDate) year, sum(i.Total), count(*)
# from invoice i
# group by year
# having year=2009 or year=2011;
# ```

# %% [markdown]
# 9. Looking at the InvoiceLine table, provide a query that COUNTs the number of line items for Invoice ID 37.
# ```mysql
# select count(*)
# from invoiceline
# where InvoiceId=37;
# ```

# %% [markdown]
# 10. Looking at the InvoiceLine table, provide a query that COUNTs the number of line items for each Invoice. HINT: GROUP BY
# ```mysql
# select InvoiceId, count(*)
# from invoiceline
# group by InvoiceId;
# ```

# %% [markdown]
# **Task # 3: Query Practice (part 2)**
#
# Use the Chinook Database and the DB Browser for your Database Server
# For each of the following exercises, provide the appropriate query (or some queries).
# Obviously provide results for each query!
# Keep your successful queries in a task3.sql file with comments.

# %% [markdown]
# 1. Provide a query that includes the track name with each invoice line item.
# ```mysql
# select t.Name, il.*
# from invoiceline il
# join track t on t.TrackId=il.TrackId;
# ```

# %% [markdown]
# 2. Provide a query that includes the purchased track name AND artist name with each invoice line item.
# ```mysql
# select t.Name trackname,art.name artist_name, il.*
# from invoiceline il
# join track t on t.TrackId=il.TrackId
# join album a on a.albumid=t.AlbumId
# join artist art on art.ArtistId=a.ArtistId;
# ```

# %% [markdown]
# 3. Provide a query that shows the # of invoices per country. HINT: GROUP BY
# ```mysql
# select billingcountry, count(*)
# from invoice
# group by billingcountry;
# ```

# %% [markdown]
# 4. Provide a query that shows the total number of tracks in each playlist. The Playlist name should be included on the resultant table.
# ```mysql
# select *
# from playlist;
# select pt.PlaylistId, p.Name, count(*)
# from playlisttrack pt
# join playlist p on p.PlaylistId=pt.PlaylistId
# group by PlaylistId;
# ```

# %% [markdown]
# 5. Provide a query that shows all the Tracks, but displays no IDs. The resultant table should include the Album name, Media type and Genre.
# ```mysql
# select t.Name trackname, a.Title albumname,m.name mediatypename, g.Name genrename
# from track t
# join album a on a.AlbumId=t.AlbumId
# join artist art on art.ArtistId=a.ArtistId
# join genre g on g.GenreId=t.GenreId
# join mediatype m on m.MediaTypeId=t.MediaTypeId;
# ```

# %% [markdown]
# 6. Provide a query that shows all Invoices but includes the # of invoice line items.
# ```mysql
# select i.*,count(*)
# from invoice i
# join invoiceline il on il.InvoiceId=i.InvoiceId
# group by i.InvoiceId;
# ```

# %% [markdown]
# 7. Provide a query that shows total sales made by each sales agent.
# ```mysql
# select concat(e.firstname,' ', e.lastname) agent_name, sum(i.Total)
# from invoice i
# join customer c on c.CustomerId=i.CustomerId
# join employee e on e.EmployeeId=c.SupportRepId
# group by agent_name;
# ```

# %% [markdown]
# 8. Which sales agent made the most in sales in 2009?
# ```mysql
# select concat(e.firstname,' ', e.lastname) agent_name, sum(i.Total) totalsum
# from invoice i
# join customer c on c.CustomerId=i.CustomerId
# join employee e on e.EmployeeId=c.SupportRepId
# where year(i.invoicedate)=2009
# group by agent_name
# order by totalsum desc
# limit 1;
# ```

# %% [markdown]
# 9. Which sales agent made the most in sales in 2010?
# ```mysql
# select concat(e.firstname,' ', e.lastname) agent_name, sum(i.Total) totalsum
# from invoice i
# join customer c on c.CustomerId=i.CustomerId
# join employee e on e.EmployeeId=c.SupportRepId
# where year(i.invoicedate)=2010
# group by agent_name
# order by totalsum desc
# limit 1;
# ```

# %% [markdown]
# 10. Which sales agent made the most in sales over all?
# ```mysql
# select concat(e.firstname,' ', e.lastname) agent_name, sum(i.Total) totalsum
# from invoice i
# join customer c on c.CustomerId=i.CustomerId
# join employee e on e.EmployeeId=c.SupportRepId
# group by agent_name
# order by totalsum desc
# limit 1;
# ```

# %% [markdown]
# **Task # 4: Query Practice (part 3)**
#
# Use the Chinook Database and the DB Browser for your Database Server
# For each of the following exercises, provide the appropriate query (or some queries).
# Obviously provide results for each query!
# Keep your successful queries in a task4.sql file with comments.

# %% [markdown]
# 1. Provide a query that shows the # of customers assigned to each sales agent.
# ```mysql
# select concat(e.firstname,' ', e.lastname) agent_name, count(distinct c.CustomerId)
# from employee e
# join customer c on e.EmployeeId=c.SupportRepId
# group by e.EmployeeId;
# ```

# %% [markdown]
# 2. Provide a query that shows the total sales per country.
# ```mysql
# select i.BillingCountry, sum(i.total)
# from invoice i
# group by i.BillingCountry
# order by 2 desc;
# ```

# %% [markdown]
# 3. Which country’s customers spent the most?
# ```mysql
# select c.Country, sum(i.total) sumtotal
# from invoice i
# join customer c on c.CustomerId=i.CustomerId
# group by c.Country
# order by sumtotal desc
# ```

# %% [markdown]
# 4. Provide a query that shows the most purchased track of 2013.
# ```mysql
# select t.name, count(*)
# from invoice i
# join invoiceline il on il.InvoiceId=i.InvoiceId
# join track t on t.TrackId=il.TrackId
# where year(i.invoicedate)=2013
# group by t.name
# order by 2 desc
# limit 1;
# ```

# %% [markdown]
# 5. Provide a query that shows the top 5 most purchased tracks over all.
# ```mysql
# select t.name, count(*)
# from invoice i
# join invoiceline il on il.InvoiceId=i.InvoiceId
# join track t on t.TrackId=il.TrackId
# group by t.name
# order by 2 desc
# limit 5;
# ```

# %% [markdown]
# 6. Provide a query that shows the top 3 best selling artists.
# ```mysql
# select art.name artist_name, count(*), sum(i.total) sumtot
# from invoice i
# join invoiceline il on il.InvoiceId=i.InvoiceId
# join track t on t.TrackId=il.TrackId
# join album a on a.AlbumId=t.AlbumId
# join artist art on art.ArtistId=a.ArtistId
# group by art.name
# order by sumtot desc
# limit 3;
# ```

# %% [markdown]
# 7. Provide a query that shows the most purchased Media Type.
# ```mysql
# select m.name, sum(i.total) sumt, count(*)
# from invoice i
# left join invoiceline il on il.InvoiceId=i.InvoiceId
# left join track t on t.TrackId=il.TrackId
# left join mediatype m on m.MediaTypeId=t.MediaTypeId
# group by m.MediaTypeId
# limit 1;
# ```

# %% [markdown]
# ## [Задачи по HUMAN RESOURCES](https://habr.com/ru/post/461567/)

# %% [markdown]
# Пока не разобрался как сфорвард-инженерить бд, но
# есть полезные ссылки:
# - https://github.com/oracle-samples/db-sample-schemas/tree/main/human_resources
# - https://github.com/oracle-samples/db-sample-schemas/releases
# - https://docs.oracle.com/en/database/oracle/oracle-database/23/comsc/installing-sample-schemas.html#GUID-9C9DEE62-E660-49F8-842B-3256ACA65346
# - https://dba.stackexchange.com/questions/52275/how-to-connect-an-oracle-db-with-mysql-workbench
# - https://github.com/nomemory/neat-sample-databases-generators#hr-schema-sql
# - https://github.com/simonkrenger/hr-schema-mysql

# %% [markdown]
# ## Всякие тесты

# %% [markdown]
#  [Тестовое Тинькофф] Звонки по дням
#
#
# Дано
# Дана следующая структура таблиц:
#
# Задание
#
# Напишите запрос, который посчитает количество звонков, сделанных между 2020-10-01 и сегодняшним днем. Полученная таблица должна состоять из двух столбцов: date и cnt_calls. В столбце date должен находиться день вызова (без времени), а в столбце "cnt_calls" должно отображаться количество звонков, совершенных в этот день.
#
# Столбцы в результате
#
# date
# cnt_calls
# Примечание: для корректной работы вашего запроса обязательно указывайте схему таблиц - tinkoff.
#
# Например, FROM tinkoff.employees.
#
# Пишите сво
# ![ваквывыавфыimage.png](attachment:image.png)

# %% [markdown]
# ```mysql
# select date(start_dttm) date, count(call_id) cnt_calls
# from tinkoff.calls
# group by date
# having date between '2020-01-01' and date(now());
# ```

# %% [markdown]
# # pandas

# %% [markdown]
# 1) создать в юпитере ячейку коммент\заголовок разного уровня
# 2) завести переменные a,b,c
# 3) создать список из а,b,c,a^2,b^2,c^2
# 4) создать кортеж —\\—
# 5) создать список из 3 элементы которого уменьшены на 3
# 6) построить функцию сумм, разности и произвденеия мин и макс abc
# 7) найти длинну списка  из 3)
# 8) добавить к нему новый список из четных числе от 10 до 40
# 9) убрать из него все нечентые числа >5
# 10) создать словарь по 2ум спискам
# 11) добавить в него элемент со случайным значением
# 12) превратить словарь  из 11) в список
# 13) превратить 12) в кортеж
# 14) Дан список: dd = [(2, 4), (4, 6), (0, 1), (5, 2), (9, 1), (3, 8)] требуется создать словарь , где  ключи - пары чисел, а values ‒ их произведение

# %%
l4=list(j for j in l3 if not (j%2 and j<=5)) 
l4
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 l4=list(j for j in l3 if not (j%2 and j<=5))
#       2 l4
#
# NameError: name 'l3' is not defined

# %%
if -3:
    1

# %%
-3%2
# Out:
# 1

# %%
a = [1,2,3,4,5] 
b = ['a','b','c','d','e'] 
ab = dict(zip(a, b)) 
ab
# Out:
# {1: 'a', 2: 'b', 3: 'c', 4: 'd', 5: 'e'}

# %%
#12) превратить словарь  из 11) в список

# %%
import random
num=random.randint(0,101)
ab[6]=num

# %%
list(ab.values())
# Out:
# ['a', 'b', 'c', 'd', 'e', 91]

# %%
list(ab.items())
# Out:
# [(1, 'a'), (2, 'b'), (3, 'c'), (4, 'd'), (5, 'e'), (6, 91)]

# %%
tuple(ab.items())
# Out:
# ((1, 'a'), (2, 'b'), (3, 'c'), (4, 'd'), (5, 'e'), (6, 91))

# %%
dd = [(2, 4), (4, 6), (0, 1), (5, 2), (9, 1), (3, 8)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [28], line 2
#       1 dd = [(2, 4), (4, 6), (0, 1), (5, 2), (9, 1), (3, 8)]
# ----> 2 {dd[i][0]*dd[i][1] for i in dd}
#
# Cell In [28], line 2, in <setcomp>(.0)
#       1 dd = [(2, 4), (4, 6), (0, 1), (5, 2), (9, 1), (3, 8)]
# ----> 2 {dd[i][0]*dd[i][1] for i in dd}
#
# TypeError: list indices must be integers or slices, not tuple

# %%
15) Дан список:
dd = [(2, 4), (4, 6), (0, 1), (5, 2), (9, 1), (3, 8)]
требуется создать словарь , где  ключи - натуральные числа от 0 до N , а values ‒ произведение кортежей списка dd

# %%
dict1={}
for i in range(len(dd.values()):
    dict1[]

# %%
1) Создайте список (list) и массив (ndarray), содержащие числа от 0 до 100 000 000.

# %%
import numpy as np
np.array(list(range(100000000)) )
# Out:
# KeyboardInterrupt

# %%
np.arange(100)

# %% [markdown]
# 1) Создайте список (list) и массив (ndarray), содержащие числа от 0 до 100 000 000.
# 2) Напишите функцию, которая вычисляет сумму всех элементов массива, используя цикл for.
# 3) Замерьте: время выполнения этой функции на списке и на массиве, время выполнения функции sum() на списке и на массиве,
# 4) время выполнения функции numpy.sum() на списке и на массиве.
# 5) Объясните полученные результаты.
#
# Везде далее запрещено использовать циклы. Numpy имеет большинство необходимых функций для операций над тензорами, например Numerical operations on arrays.
#
# 6) Загрузите и выведите на экран любую картинку. Используйте библиотеки skimage и matplotlib.
# 7) Получите и интерпретируйте размеры картинки.
# 8) Выведите верхнюю и левую половины изображения.
# 9) Выведите произвольный прямоугольник изображения.
# 10) Выведите каждый канал изображения отдельно.

# %%
import numpy as np
n_list=np.arange(10000000)
ord_list=list(range(1000))

s=n_list[0]
for i in range(len(n_list))[1:]:
    s=s+n_list[i]
s
# Out:
# 499500

# %%
def summator(x):
    x0=x[0]
    for i in x[1:]:
        x0=x0+i
    return x0

# %%
# %time summator(n_list)
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns
# 499500

# %%
summator(n_list)
# Out:
# 499500

# %%
100_000
# Out:
# 100000

# %%
# %time sum(ord_list)
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns
# 499500

# %%
# %time sum(n_list)
# Out:
# CPU times: total: 0 ns
# Wall time: 999 µs
# 499500

# %%
import numpy as np
import matplotlib.pyplot as plt
X = np.linspace(0, 2 * np.pi, 100)

Ya = np.sin(X)
Yb = np.cos(X)
plt.plot(X, Ya)
plt.plot(X, Yb)
plt.show()

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
img = mpimg.imread('asdasdsad.png')
plt.imshow(img)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [58], line 3
#       1 import matplotlib.image as mpimg
#       2 import matplotlib.pyplot as plt
# ----> 3 img = mpimg.imread('asdasdsad.png')
#       4 plt.imshow(img)
#       5 plt.show()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\image.py:1541, in imread(fname, format)
#    1534 if isinstance(fname, str) and len(parse.urlparse(fname).scheme) > 1:
#    1535     # Pillow doesn't handle URLs directly.
#    1536     raise ValueError(
#    1537         "Please open the URL for reading and pass the "
#    1538         "result to Pillow, e.g. with "
#    1539         "``np.array(PIL.Image.open(urllib.request.urlopen(url)))``."
#    1540         )
# -> 1541 with img_open(fname) as image:
#    1542     return (_pil_png_to_float_array(image)
# ...

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\79618\\Documents\\GitHub\\chereshan_notes\\notebooks'

# %% [markdown]
# # Титаник

# %% [markdown]
# Tasks:
# 1) Создайте список (list) и массив (ndarray), содержащие числа от 0 до 100 000 000.
# 2) Напишите функцию, которая вычисляет сумму всех элементов массива, используя цикл for.
# 3) Замерьте: время выполнения этой функции на списке и на массиве, время выполнения функции sum() на списке и на массиве, 4) время выполнения функции numpy.sum() на списке и на массиве.
# 5) Объясните полученные результаты.
#
# Везде далее запрещено использовать циклы. Numpy имеет большинство необходимых функций для операций над тензорами, например Numerical operations on arrays.
#
# 6) Загрузите и выведите на экран любую картинку. Используйте библиотеки skimage и matplotlib.
# 7) Получите и интерпретируйте размеры картинки.
# 8) Выведите верхнюю и левую половины изображения.
# 9) Выведите произвольный прямоугольник изображения.
# 10) Выведите каждый канал изображения отдельно.

# %% [markdown]
#   * [Pandas](http://pandas.pydata.org/)
#     - [Tutorials](http://pandas.pydata.org/pandas-docs/stable/tutorials.html)

# %% [markdown]
#
#
# ![Titanic Art](http://cdn.history.com/sites/2/2015/05/hith-titanic-tombstone-E.jpeg)
#
# ## Задания
# **Как и в предыдущем занятии здесь запрещено использовать циклы, если это специально не оговорено.**
# 1. Скачайте Titanic dataset и загрузите его в pandas.DataFrame; выведите первые 5 записей в ноутбук. Как можно интерпретировать данную таблицу?
# 2. Получите имена столбцов.
# 3. Перемешайте строки в случайном порядке.
# 4. Получите случайную подвыборку данных с возвращением и без.
# 5. Разбейте данные случайным образом на две непересекающиеся подвыборки.
# 6. Проверьте, является ли признак **Name** уникальным для каждого пассажира, если да, то сделайте его новым индексом данных.
# 7. Проверьте, содержат ли данные пропуски, если да, то заполните их.
# 8. Определите, как много пассажиров ехало первым классом.
# 9. Постройте гистограмму возрастов пассажиров.
# 10. Определите средний возраст пассажиров, медианный возраст, дисперсию.
# 11. Добавьте признак, который показывает, какой процент пассажиров имели возраст строго меньше, чем данный пассажир.
# 12. Есть ли зависимость между классом и номером билета?
# 13. Какой части пассажиров удалось выжить?
# 14. Сделайте визуализацию, позволяющую ответить на вопросы:
#   * Верно ли, что женщины выживали чаще мужчин?
#   * Верно ли, что чаще выживали пассажиры с более дорогими билетами?

# %%
import numpy as np
a = np.array([[3, 2,5], [5, 6, 8],[5, 6, 8]], float)
a[2,1]# array([[5., 6.]])
# Out:
# 6.0

# %%
ы
